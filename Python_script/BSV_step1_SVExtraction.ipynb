# %% [markdown]
# ### This notebook is for sub-volume extraction and radiomics calculation
# ### Original Author: Zhenwei Shi, Tianchen Luo, Xiaomei Huang,Zhihe Zhao
# ### Revised by Dr. S.P.

# %%
import os
import platform
import SimpleITK as sitk
import pandas as pd
import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import measure, color
import skimage.morphology as morphology

from skimage.segmentation import mark_boundaries as mark_boundaries
from skimage.segmentation import slic as slic

import shutil

# %%
def SV_split(volume, mask, out_dir):
    
    if platform.system() == 'Windows':
        separator = '\\'
    else:
        separator = '/'

    mask_array = sitk.GetArrayFromImage(sitk.ReadImage(mask))
    _, num = measure.label(mask_array, connectivity=3, return_num=True) # meature label connected regions

    for i in range(1, num + 1):
        section_volume = sitk.GetArrayFromImage(sitk.ReadImage(volume))
        section_mask = sitk.GetArrayFromImage(sitk.ReadImage(mask))

        section_mask[section_mask != i] = 0 # split sv mask
        section_mask[section_mask == i] = 1 # split sv mask

        # ----- for SV mask split ------
        print(mask.split(separator)[-1].split('.')[-3])
        svsplit_path = os.path.join(out_dir,'SVmask',mask.split(separator)[-1].split('.')[-3].split('_')[-2]) # sv path per patient
        # svsplit_path = os.path.join(out_dir,'SVmask',mask.split(separator)[-1].split('.')[-3].split('_')[-3]) # sv path per patient
        
        if not os.path.exists(svsplit_path):
            os.makedirs(svsplit_path)        
        
        section_mask_img = sitk.GetImageFromArray(section_mask)
        
        section_mask_img.SetOrigin(sitk.ReadImage(mask).GetOrigin())
        section_mask_img.SetSpacing(sitk.ReadImage(mask).GetSpacing())
        section_mask_img.SetDirection(sitk.ReadImage(mask).GetDirection())
        print(sitk.ReadImage(mask).GetOrigin())
        sitk.WriteImage(section_mask_img, # save sv mask separately
                os.path.join(svsplit_path, mask.split(separator)[-1].split('.')[-3]) + str(i)+'.nii.gz')

        # ----- for SV volume split ------
        # print(volume.split('/')[-1].split('.')[-3])
    
        # # section_volume[section_mask == 0] = 0
        # sitk.WriteImage(sitk.GetImageFromArray(section_volume), # save sv mask separately
        #         os.path.join(svsplit_path, 'SVvolume', volume.split('/')[-1].split('.')[-3])+'_SVvolume_'+ str(i)+'.nii.gz')

def check_dataset(list_volume, list_mask):
    if len(list_volume) != len(list_mask):
        raise ValueError('There exists a mismatch between two datasets.')

def mac_os_listdir(path):
    files = os.listdir(path)
    if '.DS_Store' in files:
        files.remove('.DS_Store')
        files.sort()
    return files

def get_file_num(path):
    files_num = []
    files = os.listdir(path)
    for file in files:
        if file !='.DS_Store':
            # print(file)
            num = ""
            for c in file:
                if c.isdigit():
                    num = num + c
            # print("Extracted numbers from the list : " + num)
            files_num.append(num)
    return files_num

def supervoxel(volume_list,mask_list,n_segment,supervoxel_path,center):
    print('Start super voxel processing ...')
    if not os.path.exists(supervoxel_path):
        os.makedirs(supervoxel_path)
    
    if not os.path.exists(os.path.join(supervoxel_path,center)):
        os.makedirs(os.path.join(supervoxel_path,center))

    for volume_path, mask_path in zip(volume_list, mask_list):
        
        img = sitk.GetArrayFromImage(sitk.ReadImage(volume_path))
        mask = sitk.GetArrayFromImage(sitk.ReadImage(mask_path))
        img_normalized = cv2.normalize(img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        tmp_mask = morphology.opening(mask, morphology.ball(1))

        try:
            slic_mask = slic(img_normalized, n_segment, compactness=10, mask=tmp_mask, start_label=1,
                             channel_axis=None)
        except:
            print('something wrong, SV computation failed !!!')

        mask_itk = sitk.GetImageFromArray(np.uint16(slic_mask))
        # print(sitk.ReadImage(mask_path).GetOrigin())
        mask_itk.SetOrigin(sitk.ReadImage(mask_path).GetOrigin())
        mask_itk.SetSpacing(sitk.ReadImage(mask_path).GetSpacing())
        mask_itk.SetDirection(sitk.ReadImage(mask_path).GetDirection())
        # save slic_mask
        # Determine the correct path separator based on the operating system
        if platform.system() == 'Windows':
            separator = '\\'
        else:
            separator = '/'
        output_name = os.path.join(supervoxel_path,center,center+'_' + mask_path.split(separator)[-1].split('.')[0] + '_SVmask.nii.gz')
        print(output_name)
        sitk.WriteImage(mask_itk, output_name)
        print('{} is Done'.format(output_name.split(separator)[-1]))

#TODO
# def resampe():
# def normalization():

# %% [markdown]
# #### Set User Parameters

# %%
# User parameters - path

# data_dir = r'/media/zhenwei/3b5e8580-3829-4c0a-b2fa-ce0cd26a7d93/Data/Breast_MRI/SY'  # specify where your data store
data_dir = r'/media/peng/data/02_radiomics/chenquan/new3/radiomics'
code_dir = r'/home/peng/00_github/03_radiomics/240612_QMITH_SP/Python_script' # as a working directory

# User parameters - sub-vlume
n_segment = 100
center = 'hn'
# center = 'hn'

# User parameters - radiomics

# casetable_dir = r'../output/CaseTable'
# rf_dir = r'../output/RF'
casetable_dir= os.path.join(data_dir,'output','CaseTable')
rf_dir = os.path.join(data_dir,'output','RF')
# --------------------------------------------------------
tmp_volume = os.path.join(data_dir,'tmp_dir','VolumeDir')
tmp_mask = os.path.join(data_dir,'tmp_dir','MaskDir')
out_dir = os.path.join(data_dir,'output')
SVS_dir = os.path.join(out_dir,'SV','SVSplit')
SVSmask_dir = os.path.join(out_dir,'SV','SVSplit','SVmask')
SVSvolume_dir = os.path.join(out_dir,'SV','SVSplit','SVvolume')
SVwhole_dir = os.path.join(out_dir,'SV','SVWhole')

# --------------------------------------------------------
## remove files from temparal directory
if os.path.isdir(tmp_volume):
    shutil.rmtree(tmp_volume)

if os.path.isdir(tmp_mask):
    shutil.rmtree(tmp_mask)
# --------------------------------------------------------
# check if dirs exist
dir_list = [out_dir,tmp_volume,tmp_mask,SVS_dir,SVSmask_dir,SVSvolume_dir,SVwhole_dir,casetable_dir,rf_dir]
for dir in dir_list:
    if not os.path.exists(dir):
        os.makedirs(dir)

# %%
# for users 
# specify image nii dir and mask nii dir

volume_list= glob.glob(os.path.join(data_dir,'image','*'))
mask_list = glob.glob(os.path.join(data_dir,'mask','*'))

volume_list.sort()
mask_list.sort()

# check if they are in the same length
#TODO check id and pre/post
check_dataset(volume_list, mask_list)

# %% [markdown]
# #### Implementation of sub-volume calculation

# %%
# copy files to fixed and temparal dirs for easy process 
for volume, mask in zip(volume_list,mask_list):
    shutil.copy2(volume,os.path.join(data_dir,'tmp_dir','VolumeDir'))
    shutil.copy2(mask,os.path.join(data_dir,'tmp_dir','MaskDir'))

volume_list_new = glob.glob(os.path.join(data_dir,'tmp_dir','VolumeDir','*'))
mask_list_new = glob.glob(os.path.join(data_dir,'tmp_dir','MaskDir','*'))
volume_list_new.sort()
mask_list_new.sort()

# check if they are in the same length
check_dataset(volume_list_new, mask_list_new)
print('Dataset checked!')

# supervoxel calculation by slic, 
supervoxel(volume_list_new, mask_list_new, n_segment,SVwhole_dir,center)
print('Supervoxel Done')

sv_list = mac_os_listdir(os.path.join(SVwhole_dir,center))
sv_list.sort()
sv_list = [os.path.join(SVwhole_dir,center, file) for file in sv_list]
check_dataset(volume_list_new, sv_list)

# supervoxel split for further processing
print('Start SV split processing ...')
for volume_i, mask_j in zip(volume_list_new, sv_list):
    SV_split(volume_i, mask_j, SVS_dir)
print('SV split done')
# Out:
# Dataset checked!
# Start super voxel processing ...
# /media/peng/data/02_radiomics/chenquan/new3/radiomics/output/SV/SVWhole/hn/hn_sub001_SVmask.nii.gz
# hn_sub001_SVmask.nii.gz is Done
# /media/peng/data/02_radiomics/chenquan/new3/radiomics/output/SV/SVWhole/hn/hn_sub002_SVmask.nii.gz
# hn_sub002_SVmask.nii.gz is Done
# /media/peng/data/02_radiomics/chenquan/new3/radiomics/output/SV/SVWhole/hn/hn_sub003_SVmask.nii.gz
# hn_sub003_SVmask.nii.gz is Done
# Supervoxel Done
# Start SV split processing ...
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub001_SVmask
# (98.09551239013672, 130.1951904296875, -133.7318115234375)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub002_SVmask
# (79.89177703857422, 113.169921875, -116.21049499511719)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# hn_sub003_SVmask
# (-131.2487335205078, -114.07168579101562, -39.051326751708984)
# SV split done

# %% [markdown]
# #### Generate case table for radiomics

# %%
# for radiomics - prepare casetable
image_files = volume_list_new
mask_files = os.listdir(SVSmask_dir)
image_files.sort()
mask_files.sort()

check_dataset(image_files, mask_files)

if platform.system() == 'Windows':
    separator = '\\'
else:
    separator = '/'

for i in range(0,len(image_files)):
    img_id = image_files[i].split(separator)[-1].split('_')[-1].split('.')[-3]
    # print(image_files[i].split('separator')[-1].split('_')[-1].split('.')[-3])
    SV_files = mac_os_listdir(os.path.join(SVSmask_dir,mask_files[i]))
    SV_files.sort()
    CaseTable = pd.DataFrame()
    for j in range(0,len(SV_files)):
        ptid = pd.Series({'ID':img_id+'_'+SV_files[j].split('.')[-3]})
        # print(SV_files[j].split('.')[-3])
        print(SV_files[j])
        
        Image_path = pd.Series({'Image':image_files[i]})
       
        Mask_path = pd.Series({'Mask':os.path.join(SVSmask_dir,mask_files[i],SV_files[j])})

        # case_id_img = ptid.append(Image_path)
        case_id_img =  pd.concat([ptid, Image_path], axis=0, ignore_index=True)

        # case_id_img_mask = case_id_img.append(Mask_path)
        case_id_img_mask=pd.concat([case_id_img, Mask_path], axis=0, ignore_index=True)
        
        # print(case_id_img_mask)
        CaseTable = pd.concat([CaseTable,case_id_img_mask],axis = 1)
        
        # print(CaseTable)    # generate case table for radiomics calculation, including ID, image and mask path
    # CaseTable=CaseTable.iloc[1:] 
    # print(CaseTableT)
    # CaseTableT =  CaseTableT
    # print(CaseTable)
    CaseTableT=CaseTable.T
    CaseTableT.columns = ['ID', 'Image', 'Mask']
    CaseTableT.to_csv(os.path.join(casetable_dir,img_id +'_CaseTable.csv'),index=False)
# Out:
# hn_sub001_SVmask1.nii.gz
# hn_sub001_SVmask10.nii.gz
# hn_sub001_SVmask100.nii.gz
# hn_sub001_SVmask101.nii.gz
# hn_sub001_SVmask102.nii.gz
# hn_sub001_SVmask103.nii.gz
# hn_sub001_SVmask104.nii.gz
# hn_sub001_SVmask105.nii.gz
# hn_sub001_SVmask106.nii.gz
# hn_sub001_SVmask107.nii.gz
# hn_sub001_SVmask108.nii.gz
# hn_sub001_SVmask11.nii.gz
# hn_sub001_SVmask12.nii.gz
# hn_sub001_SVmask13.nii.gz
# hn_sub001_SVmask14.nii.gz
# hn_sub001_SVmask15.nii.gz
# hn_sub001_SVmask16.nii.gz
# hn_sub001_SVmask17.nii.gz
# hn_sub001_SVmask18.nii.gz
# hn_sub001_SVmask19.nii.gz
# hn_sub001_SVmask2.nii.gz
# hn_sub001_SVmask20.nii.gz
# hn_sub001_SVmask21.nii.gz
# hn_sub001_SVmask22.nii.gz
# hn_sub001_SVmask23.nii.gz
# hn_sub001_SVmask24.nii.gz
# hn_sub001_SVmask25.nii.gz
# hn_sub001_SVmask26.nii.gz
# hn_sub001_SVmask27.nii.gz
# hn_sub001_SVmask28.nii.gz
# hn_sub001_SVmask29.nii.gz
# hn_sub001_SVmask3.nii.gz
# hn_sub001_SVmask30.nii.gz
# hn_sub001_SVmask31.nii.gz
# hn_sub001_SVmask32.nii.gz
# hn_sub001_SVmask33.nii.gz
# hn_sub001_SVmask34.nii.gz
# hn_sub001_SVmask35.nii.gz
# hn_sub001_SVmask36.nii.gz
# hn_sub001_SVmask37.nii.gz
# hn_sub001_SVmask38.nii.gz
# hn_sub001_SVmask39.nii.gz
# hn_sub001_SVmask4.nii.gz
# hn_sub001_SVmask40.nii.gz
# hn_sub001_SVmask41.nii.gz
# hn_sub001_SVmask42.nii.gz
# hn_sub001_SVmask43.nii.gz
# hn_sub001_SVmask44.nii.gz
# hn_sub001_SVmask45.nii.gz
# hn_sub001_SVmask46.nii.gz
# hn_sub001_SVmask47.nii.gz
# hn_sub001_SVmask48.nii.gz
# hn_sub001_SVmask49.nii.gz
# hn_sub001_SVmask5.nii.gz
# hn_sub001_SVmask50.nii.gz
# hn_sub001_SVmask51.nii.gz
# hn_sub001_SVmask52.nii.gz
# hn_sub001_SVmask53.nii.gz
# hn_sub001_SVmask54.nii.gz
# hn_sub001_SVmask55.nii.gz
# hn_sub001_SVmask56.nii.gz
# hn_sub001_SVmask57.nii.gz
# hn_sub001_SVmask58.nii.gz
# hn_sub001_SVmask59.nii.gz
# hn_sub001_SVmask6.nii.gz
# hn_sub001_SVmask60.nii.gz
# hn_sub001_SVmask61.nii.gz
# hn_sub001_SVmask62.nii.gz
# hn_sub001_SVmask63.nii.gz
# hn_sub001_SVmask64.nii.gz
# hn_sub001_SVmask65.nii.gz
# hn_sub001_SVmask66.nii.gz
# hn_sub001_SVmask67.nii.gz
# hn_sub001_SVmask68.nii.gz
# hn_sub001_SVmask69.nii.gz
# hn_sub001_SVmask7.nii.gz
# hn_sub001_SVmask70.nii.gz
# hn_sub001_SVmask71.nii.gz
# hn_sub001_SVmask72.nii.gz
# hn_sub001_SVmask73.nii.gz
# hn_sub001_SVmask74.nii.gz
# hn_sub001_SVmask75.nii.gz
# hn_sub001_SVmask76.nii.gz
# hn_sub001_SVmask77.nii.gz
# hn_sub001_SVmask78.nii.gz
# hn_sub001_SVmask79.nii.gz
# hn_sub001_SVmask8.nii.gz
# hn_sub001_SVmask80.nii.gz
# hn_sub001_SVmask81.nii.gz
# hn_sub001_SVmask82.nii.gz
# hn_sub001_SVmask83.nii.gz
# hn_sub001_SVmask84.nii.gz
# hn_sub001_SVmask85.nii.gz
# hn_sub001_SVmask86.nii.gz
# hn_sub001_SVmask87.nii.gz
# hn_sub001_SVmask88.nii.gz
# hn_sub001_SVmask89.nii.gz
# hn_sub001_SVmask9.nii.gz
# hn_sub001_SVmask90.nii.gz
# hn_sub001_SVmask91.nii.gz
# hn_sub001_SVmask92.nii.gz
# hn_sub001_SVmask93.nii.gz
# hn_sub001_SVmask94.nii.gz
# hn_sub001_SVmask95.nii.gz
# hn_sub001_SVmask96.nii.gz
# hn_sub001_SVmask97.nii.gz
# hn_sub001_SVmask98.nii.gz
# hn_sub001_SVmask99.nii.gz
# hn_sub002_SVmask1.nii.gz
# hn_sub002_SVmask10.nii.gz
# hn_sub002_SVmask100.nii.gz
# hn_sub002_SVmask101.nii.gz
# hn_sub002_SVmask102.nii.gz
# hn_sub002_SVmask11.nii.gz
# hn_sub002_SVmask12.nii.gz
# hn_sub002_SVmask13.nii.gz
# hn_sub002_SVmask14.nii.gz
# hn_sub002_SVmask15.nii.gz
# hn_sub002_SVmask16.nii.gz
# hn_sub002_SVmask17.nii.gz
# hn_sub002_SVmask18.nii.gz
# hn_sub002_SVmask19.nii.gz
# hn_sub002_SVmask2.nii.gz
# hn_sub002_SVmask20.nii.gz
# hn_sub002_SVmask21.nii.gz
# hn_sub002_SVmask22.nii.gz
# hn_sub002_SVmask23.nii.gz
# hn_sub002_SVmask24.nii.gz
# hn_sub002_SVmask25.nii.gz
# hn_sub002_SVmask26.nii.gz
# hn_sub002_SVmask27.nii.gz
# hn_sub002_SVmask28.nii.gz
# hn_sub002_SVmask29.nii.gz
# hn_sub002_SVmask3.nii.gz
# hn_sub002_SVmask30.nii.gz
# hn_sub002_SVmask31.nii.gz
# hn_sub002_SVmask32.nii.gz
# hn_sub002_SVmask33.nii.gz
# hn_sub002_SVmask34.nii.gz
# hn_sub002_SVmask35.nii.gz
# hn_sub002_SVmask36.nii.gz
# hn_sub002_SVmask37.nii.gz
# hn_sub002_SVmask38.nii.gz
# hn_sub002_SVmask39.nii.gz
# hn_sub002_SVmask4.nii.gz
# hn_sub002_SVmask40.nii.gz
# hn_sub002_SVmask41.nii.gz
# hn_sub002_SVmask42.nii.gz
# hn_sub002_SVmask43.nii.gz
# hn_sub002_SVmask44.nii.gz
# hn_sub002_SVmask45.nii.gz
# hn_sub002_SVmask46.nii.gz
# hn_sub002_SVmask47.nii.gz
# hn_sub002_SVmask48.nii.gz
# hn_sub002_SVmask49.nii.gz
# hn_sub002_SVmask5.nii.gz
# hn_sub002_SVmask50.nii.gz
# hn_sub002_SVmask51.nii.gz
# hn_sub002_SVmask52.nii.gz
# hn_sub002_SVmask53.nii.gz
# hn_sub002_SVmask54.nii.gz
# hn_sub002_SVmask55.nii.gz
# hn_sub002_SVmask56.nii.gz
# hn_sub002_SVmask57.nii.gz
# hn_sub002_SVmask58.nii.gz
# hn_sub002_SVmask59.nii.gz
# hn_sub002_SVmask6.nii.gz
# hn_sub002_SVmask60.nii.gz
# hn_sub002_SVmask61.nii.gz
# hn_sub002_SVmask62.nii.gz
# hn_sub002_SVmask63.nii.gz
# hn_sub002_SVmask64.nii.gz
# hn_sub002_SVmask65.nii.gz
# hn_sub002_SVmask66.nii.gz
# hn_sub002_SVmask67.nii.gz
# hn_sub002_SVmask68.nii.gz
# hn_sub002_SVmask69.nii.gz
# hn_sub002_SVmask7.nii.gz
# hn_sub002_SVmask70.nii.gz
# hn_sub002_SVmask71.nii.gz
# hn_sub002_SVmask72.nii.gz
# hn_sub002_SVmask73.nii.gz
# hn_sub002_SVmask74.nii.gz
# hn_sub002_SVmask75.nii.gz
# hn_sub002_SVmask76.nii.gz
# hn_sub002_SVmask77.nii.gz
# hn_sub002_SVmask78.nii.gz
# hn_sub002_SVmask79.nii.gz
# hn_sub002_SVmask8.nii.gz
# hn_sub002_SVmask80.nii.gz
# hn_sub002_SVmask81.nii.gz
# hn_sub002_SVmask82.nii.gz
# hn_sub002_SVmask83.nii.gz
# hn_sub002_SVmask84.nii.gz
# hn_sub002_SVmask85.nii.gz
# hn_sub002_SVmask86.nii.gz
# hn_sub002_SVmask87.nii.gz
# hn_sub002_SVmask88.nii.gz
# hn_sub002_SVmask89.nii.gz
# hn_sub002_SVmask9.nii.gz
# hn_sub002_SVmask90.nii.gz
# hn_sub002_SVmask91.nii.gz
# hn_sub002_SVmask92.nii.gz
# hn_sub002_SVmask93.nii.gz
# hn_sub002_SVmask94.nii.gz
# hn_sub002_SVmask95.nii.gz
# hn_sub002_SVmask96.nii.gz
# hn_sub002_SVmask97.nii.gz
# hn_sub002_SVmask98.nii.gz
# hn_sub002_SVmask99.nii.gz
# hn_sub003_SVmask1.nii.gz
# hn_sub003_SVmask10.nii.gz
# hn_sub003_SVmask100.nii.gz
# hn_sub003_SVmask101.nii.gz
# hn_sub003_SVmask102.nii.gz
# hn_sub003_SVmask103.nii.gz
# hn_sub003_SVmask104.nii.gz
# hn_sub003_SVmask11.nii.gz
# hn_sub003_SVmask12.nii.gz
# hn_sub003_SVmask13.nii.gz
# hn_sub003_SVmask14.nii.gz
# hn_sub003_SVmask15.nii.gz
# hn_sub003_SVmask16.nii.gz
# hn_sub003_SVmask17.nii.gz
# hn_sub003_SVmask18.nii.gz
# hn_sub003_SVmask19.nii.gz
# hn_sub003_SVmask2.nii.gz
# hn_sub003_SVmask20.nii.gz
# hn_sub003_SVmask21.nii.gz
# hn_sub003_SVmask22.nii.gz
# hn_sub003_SVmask23.nii.gz
# hn_sub003_SVmask24.nii.gz
# hn_sub003_SVmask25.nii.gz
# hn_sub003_SVmask26.nii.gz
# hn_sub003_SVmask27.nii.gz
# hn_sub003_SVmask28.nii.gz
# hn_sub003_SVmask29.nii.gz
# hn_sub003_SVmask3.nii.gz
# hn_sub003_SVmask30.nii.gz
# hn_sub003_SVmask31.nii.gz
# hn_sub003_SVmask32.nii.gz
# hn_sub003_SVmask33.nii.gz
# hn_sub003_SVmask34.nii.gz
# hn_sub003_SVmask35.nii.gz
# hn_sub003_SVmask36.nii.gz
# hn_sub003_SVmask37.nii.gz
# hn_sub003_SVmask38.nii.gz
# hn_sub003_SVmask39.nii.gz
# hn_sub003_SVmask4.nii.gz
# hn_sub003_SVmask40.nii.gz
# hn_sub003_SVmask41.nii.gz
# hn_sub003_SVmask42.nii.gz
# hn_sub003_SVmask43.nii.gz
# hn_sub003_SVmask44.nii.gz
# hn_sub003_SVmask45.nii.gz
# hn_sub003_SVmask46.nii.gz
# hn_sub003_SVmask47.nii.gz
# hn_sub003_SVmask48.nii.gz
# hn_sub003_SVmask49.nii.gz
# hn_sub003_SVmask5.nii.gz
# hn_sub003_SVmask50.nii.gz
# hn_sub003_SVmask51.nii.gz
# hn_sub003_SVmask52.nii.gz
# hn_sub003_SVmask53.nii.gz
# hn_sub003_SVmask54.nii.gz
# hn_sub003_SVmask55.nii.gz
# hn_sub003_SVmask56.nii.gz
# hn_sub003_SVmask57.nii.gz
# hn_sub003_SVmask58.nii.gz
# hn_sub003_SVmask59.nii.gz
# hn_sub003_SVmask6.nii.gz
# hn_sub003_SVmask60.nii.gz
# hn_sub003_SVmask61.nii.gz
# hn_sub003_SVmask62.nii.gz
# hn_sub003_SVmask63.nii.gz
# hn_sub003_SVmask64.nii.gz
# hn_sub003_SVmask65.nii.gz
# hn_sub003_SVmask66.nii.gz
# hn_sub003_SVmask67.nii.gz
# hn_sub003_SVmask68.nii.gz
# hn_sub003_SVmask69.nii.gz
# hn_sub003_SVmask7.nii.gz
# hn_sub003_SVmask70.nii.gz
# hn_sub003_SVmask71.nii.gz
# hn_sub003_SVmask72.nii.gz
# hn_sub003_SVmask73.nii.gz
# hn_sub003_SVmask74.nii.gz
# hn_sub003_SVmask75.nii.gz
# hn_sub003_SVmask76.nii.gz
# hn_sub003_SVmask77.nii.gz
# hn_sub003_SVmask78.nii.gz
# hn_sub003_SVmask79.nii.gz
# hn_sub003_SVmask8.nii.gz
# hn_sub003_SVmask80.nii.gz
# hn_sub003_SVmask81.nii.gz
# hn_sub003_SVmask82.nii.gz
# hn_sub003_SVmask83.nii.gz
# hn_sub003_SVmask84.nii.gz
# hn_sub003_SVmask85.nii.gz
# hn_sub003_SVmask86.nii.gz
# hn_sub003_SVmask87.nii.gz
# hn_sub003_SVmask88.nii.gz
# hn_sub003_SVmask89.nii.gz
# hn_sub003_SVmask9.nii.gz
# hn_sub003_SVmask90.nii.gz
# hn_sub003_SVmask91.nii.gz
# hn_sub003_SVmask92.nii.gz
# hn_sub003_SVmask93.nii.gz
# hn_sub003_SVmask94.nii.gz
# hn_sub003_SVmask95.nii.gz
# hn_sub003_SVmask96.nii.gz
# hn_sub003_SVmask97.nii.gz
# hn_sub003_SVmask98.nii.gz
# hn_sub003_SVmask99.nii.gz

# %% [markdown]
# #### Implementation of radiomics calculation

# %%
# for radiomics calculation
# recommand to run it on command line
# %run ../Pre_processing/batchProcessingWithPandas_split.py
